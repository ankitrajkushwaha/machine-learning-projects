# %%
# project 1  step 1: import
import numpy as np
import pandas as pd
import matplotlib

# %%
# step1 : import
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# step 2 : data upload
df = pd.read_csv("data.csv")

# %%
 #step 3: x and y define
# input feature(x)
X = df[['bedrooms','bathrooms','sqft_living','sqft_lot','floors','condition','yr_built']]
# target(y)
Y = df['price']

# %%
#step 4: model train
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,random_state = 42)

# %%
# step 5: model decide
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
# step 6 prediction
Y_pred = model.predict(X_test)
new_house = [[3,2,1800,6000,1,3,2010]]
predicted_price = model.predict(new_house)
print("predicted price:",predicted_price[0])
# Out:
# predicted price: 307233.9458983317
# C:\Users\ankit\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
plt.scatter(Y_test,Y_pred)
plt.xlabel("actual price")
plt.ylabel("predicted_price")
plt.title("actual data vs predicted data")
plt.show()
